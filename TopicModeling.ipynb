# %% [markdown]
# # Crunchbase HW: Assign Categories to Articles

# %% [markdown]
# The goal of this project is to be able to accurately categorize various articles in order to determine which articles are the most relevant to the needs of Crunchbase.

# %%
import pandas as pd

# %% [markdown]
# First, let's read in our data. It's in json format, so we can use the pandas built-in json reader to read the data

# %%
data = pd.read_json('corpus.txt', lines=True)
newsDF = pd.DataFrame(data)
newsDF = newsDF[newsDF.columns[::-1]]

# %%
newsDF.head()
# Out:
#                                                title  \
# 0  There’s Reason to Be Skeptical of a Tesla-Powe...
# 1  Police: Threats to West Des Moines students we...
# 2            Gunman reserved two rooms at Blackstone
# 3  No. 5 Georgia Bulldogs, Vanderbilt Commodores ...
# 4  Craig Robinson and Adam Scott buddy up in Fox'...
#
#                                         thumbnailUrl  \
# 0  {'string': 'http://www.slate.com/content/dam/s...
# 1  {'string': 'https://www.gannett-cdn.com/-mm-/9...
# 2  {'string': 'http://www.trbimg.com/img-59d66185...
# 3  {'string': 'https://cdnph.upi.com/svc/sv/upi/2...
# 4  {'string': 'http://www.trbimg.com/img-59cea4c3...
#
#                                                 text  \
# 0  Joe Raedle/Getty Images\nLast week, I wrote a ...
# 1  Zach Boyden-Holmes/The Register\nPolice have i...
# 2  Chicago police are investigating whether Steph...
# 3  NASHVILLE, Tenn. -- No. 5 Georgia, coming off ...
# 4
#
#                                                 tags  \
# 0  [{'score': 0.75, 'count': 10, 'label': 'Puerto...
# 1  [{'score': 0.65, 'count': 3, 'label': 'West De...
# 2  [{'score': 0.38, 'count': 1, 'label': 'The Bla...
# 3                                                 []
# 4                                                 []
#
#                             siteName  \
# 0       {'string': 'Slate Magazine'}
# 1  {'string': 'Des Moines Register'}
# 2   {'string': 'chicagotribune.com'}
# 3                  {'string': 'UPI'}
# 4   {'string': 'chicagotribune.com'}
#
#                                              pageUrl     humanLanguage html  \
# 0  http://www.slate.com/articles/technology/techn...  {'string': 'en'}
# 1  http://www.desmoinesregister.com/story/news/cr...  {'string': 'en'}
# 2  http://www.chicagotribune.com/news/local/break...  {'string': 'en'}
# 3  https://www.upi.com/Sports_News/College-Footba...  {'string': 'en'}
# 4  http://www.chicagotribune.com/entertainment/tv...  {'string': 'en'}
#
#             date                                  crawlName  \
# 0  1507313040000                   {'string': 'slate_tech'}
# 1  1507248000000   {'string': 'demoines_register_business'}
# 2  1507161600000      {'string': 'chicago_tribue_business'}
# 3  1507055340000                 {'string': 'upi_business'}
# 4  1506776400000  {'string': 'cb3_chicago_tribue_business'}
#
#                           author
# 0  {'string': 'Eleanor Cummins'}
# 1    {'string': 'Kelly McGowan'}
# 2  {'string': 'Chicago Tribune'}
# 3                           None
# 4                           None

# %% [markdown]
# # Clean the Data

# %% [markdown]
# It's important first that we identify what columns/features are going to be the most important to us. In my opinion, the 'text' column will be the most useful for the topic modeling process, so we will focus on that.
#
# We start by importing the required nltk libraries, and add to the stopword list to clean the text of any words that we do not find important in classifying the topic.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string

# %%
stop = set(nltk.corpus.stopwords.words('english'))
# newStopWords = ['string', 'said', 'would', 'you', 'year', 'one','also', 'ha', '-', 'and', 'andn', 'n','inn', 'ofn', 'ofnn', 'andnn', 'ann','thenn','tonn']
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()
stop.update(['string', 'said', 'would', 'you', 'year', 'one','also', 'ha', '–', 'and','like', 'get', 'andn', 'n','inn', 'ofn', 'ofnn', 'andnn', 'ann','thenn','tonn', 'u'])
def clean_text(doc):
    stop_remove = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_remove = ''.join(ch for ch in stop_remove if ch not in exclude)
    cleaned = " ".join(lemma.lemmatize(word) for word in punc_remove.split())
    return cleaned

# %%
import numpy as np
cleaned = pd.Series(newsDF['text'].astype(str)).apply(clean_text)

# %% [markdown]
# I do a second cleaning to remove some of the other words that become apparent after the first cleaning.

# %%
# second cleaning

new_cleaned = cleaned.apply(clean_text)

# %% [markdown]
# Now that the articles have been stripped of their stopwords, we can also drop any columns we don't really need to worry about

# %%
newsDF['cleaned_text'] = new_cleaned
newsDF.head()
newsDF_copy = newsDF.drop(['thumbnailUrl', 'tags', 'siteName', 'pageUrl', 'humanLanguage', 'html', 'crawlName', 'author'], axis = 1)

newsDF_copy.head(10)
# Out:
#                                                title  \
# 0  There’s Reason to Be Skeptical of a Tesla-Powe...
# 1  Police: Threats to West Des Moines students we...
# 2            Gunman reserved two rooms at Blackstone
# 3  No. 5 Georgia Bulldogs, Vanderbilt Commodores ...
# 4  Craig Robinson and Adam Scott buddy up in Fox'...
# 5  'Mark Felt: The Man Who Brought Down the White...
# 6  Stars tweet support for Ashley Judd after she ...
# 7                      < Review: 'Blade Runner 2049'
# 8  Hurricane Nate threatens US central Gulf Coast...
# 9                         Board Meeting On 03 Nov 17
#
#                                                 text           date  \
# 0  Joe Raedle/Getty Images\nLast week, I wrote a ...  1507313040000
# 1  Zach Boyden-Holmes/The Register\nPolice have i...  1507248000000
# 2  Chicago police are investigating whether Steph...  1507161600000
# 3  NASHVILLE, Tenn. -- No. 5 Georgia, coming off ...  1507055340000
# 4                                                     1506776400000
# 5                                                     1507215120000
# 6  OSCAR-WINNER Brie Larson has spoken out in sup...  1507303440000
# 7  RACHEL MARTIN, HOST:\n"Blade Runner" is back. ...  1507248000000
# 8  MANAGUA: Hurricane Nate may strengthen on Satu...  1507397400000
# 9  Board meeting for approval of Q2 unaudited fin...  1507334400000
#
#                                         cleaned_text
# 0  joe raedlegetty image last week wrote story sl...
# 1  zach boydenholmesthe register police identifie...
# 2  chicago police investigating whether stephen p...
# 3  nashville tenn 5 georgia coming two impressive...
# 4
# 5
# 6  oscarwinner brie larson spoken support fellow ...
# 7  rachel martin host blade runner back sure harr...
# 8  managua hurricane nate may strengthen saturday...
# 9  board meeting approval q2 unaudited financial ...

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# At this point, we are ready to prepare our cleaned text for topic modeling. We will convert the cleaned text for each document into an array of strings to tokenize.

# %%
import numpy as np

# convert the cleaned text to an array of strings
clean_text_arr = newsDF['cleaned_text'].astype(str)
clean_text_arr = np.asarray(clean_text_arr)
clean_text_arr = [i.split(" ") for i in clean_text_arr]

# %% [markdown]
# Latent Dirichlet Allocation (LDA) is going to be the method of choice when it comes to topic modeling. Essentially we are going to create a dictionary before converting to the bag-of-words model. This dictionary will be saved for when we identify the topics.

# %%
import gensim
from gensim import corpora

dictionary = corpora.Dictionary(clean_text_arr)
corpus = [dictionary.doc2bow(text) for text in clean_text_arr]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %% [markdown]
# I am going off the assumption that there will be about 5 topics: Miscellaneous news, culture, sports, business, and tech.

# %%
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=50)

topics = ldamodel.print_topics(num_words=3)
for topic in topics:
    print(topic)
# Out:
# (0, '0.010*"game" + 0.006*"team" + 0.006*"first"')
# (1, '0.005*"time" + 0.004*"people" + 0.004*"new"')
# (2, '0.005*"state" + 0.004*"trump" + 0.003*"people"')
# (3, '0.008*"company" + 0.006*"market" + 0.005*"business"')
# (4, '0.005*"new" + 0.004*"user" + 0.004*"device"')

# %% [markdown]
# The output above can help us decipher more concrete labels to these topics. 'Game', 'team', 'first' sounds like sports. 'Time', 'people', 'new' sounds like it could be entertainment. Words like 'state', 'trump' and 'people' make me think of a domestic news article. Then topic 3 sounds like it business related, and topic 4 sounds like it's related to tech/science.
#
# I then create a dictionary corresponding to these labels.

# %%
topic_dict = {0:'sports', 1:'entertainment/culture', 2:'domestic/local news', 3:'business', 4:'tech'}

# %% [markdown]
# The function below is meant to take our array of the tokenized clean text and apply a label from the dictionary above by picking the topic that produces the highest probability for a given document.

# %%
from operator import itemgetter

def get_topic(doc):
    test_run = doc
    test_run = dictionary.doc2bow(test_run)
    topic_pred = ldamodel.get_document_topics(test_run)
    topic_sort = sorted(topic_pred, key=itemgetter(1), reverse=True)
    return (topic_dict.get(topic_sort[0][0]))
                        
clean_series = pd.Series(clean_text_arr)

# %% [markdown]
# With the new set of topics we now have from labeling the articles, we can now append this column to the data frame. In my opinion, the categorize 'business' and 'tech' seem to be the most relevant to the interests of Crunchbase.

# %%
newsDF_copy['category'] = clean_series.apply(get_topic)
newsDF_copy.drop(columns=['date']).head(100)
# Out:
#                                                 title  \
# 0   There’s Reason to Be Skeptical of a Tesla-Powe...
# 1   Police: Threats to West Des Moines students we...
# 2             Gunman reserved two rooms at Blackstone
# 3   No. 5 Georgia Bulldogs, Vanderbilt Commodores ...
# 4   Craig Robinson and Adam Scott buddy up in Fox'...
# 5   'Mark Felt: The Man Who Brought Down the White...
# 6   Stars tweet support for Ashley Judd after she ...
# 7                       < Review: 'Blade Runner 2049'
# 8   Hurricane Nate threatens US central Gulf Coast...
# 9                          Board Meeting On 03 Nov 17
# 10                  How to cope after a mass shooting
# 11  Ericsson 'regrets' cuts as more than 100 of it...
# 12  How ‘smart’ speakers and facilities could chan...
# 13       Venture Capital Database 2017 Now Available!
# 14     We Need A Collective Push To End Site Spoofing
# 15  Nobel Prize for Physics awarded to team who fo...
# 16          Wauconda library launches customer survey
# 17   Judge delays Waymo/Uber trial until December 4th
# 18  The booming business of music festivals has a ...
# 19  Hurricane Nate heads for Louisiana and Alabama...
# 20  Mexico Arrests Ex-Governor Who Is Fugitive Fro...
# 21  ‘Scandal’ Season 7 Star Kerry Washington Hints...
# 22  Miami University RedHawks hockey honors Brenda...
# 23  Carlos Correa leads Astros to second win in a ...
# 24  Here are all the other fatal shootings from Su...
# 25           How to handle heat, humidity on race day
# 26  Moody’s Upgrades 4Finance Credit Ratings as On...
# 27  KEMP Technologies Drives Faster Websites with ...
# 28  Bay Area political events: Media coverage, sin...
# 29  Peggy Kinnane's recognized for employing indiv...
# ..                                                ...
# 70  He rescued a kidnapped Minnesota girl. Here’s ...
# 71  With Reference To Above, Please Find Voting Re...
# 72       Venture Capital Database 2017 Now Available!
# 73  Cytel announces further expansion in Europe wi...
# 74  George Pell sex offences 'impossible', his law...
# 75  House Dems: Show us ex-health chief's check fo...
# 76  N.J. doomsday prepper sends all of his food to...
# 77  Gun silencers make it easier to commit crimes ...
# 78  Pitt's 'selfless' Mike Herndon flips from back...
# 79  Google vies to make even smarter phones, speak...
# 80  Metrolink unveils first of 40 clean diesel loc...
# 81  Gov't would defer sales tax hike if economy wo...
# 82  Were Iowa regents' private rendezvous with Har...
# 83  Gulf Coast braces for fast-moving blast of tro...
# 84  Whitehall not funding fire safety work promise...
# 85  Coach Mike Sullivan insists the Penguins will ...
# 86  Vegas Golden Knights Season Preview: 10 fearle...
# 87     The best College GameDay signs from Fort Worth
# 88  Everyone loves a tax cut. But is it good for o...
# 89  Restrictions on 'bump stock' would take action...
# 90  FIFA U-17 World Cup: Mata strike helps New Zea...
# 91  Life And Death In Puerto Rico, And ‘Alternativ...
# 92         Kangaroos block road with fierce fistfight
# 93  PES 2018: The game still needs work before it ...
# 94  San Jacinto seventh grader rushes for 313 yard...
# 95                 Hands-on with Google’s new Pixel 2
# 96  Kyrgios finds purpose in helping underprivileg...
# 97  The collapse of Monarch: inside the doomed air...
# 98  Ready to wear fashion for spring-summer 2018 h...
# 99  Iowa State flag-plant gives Mayfield, Oklahoma...
#
#                                                  text  \
# 0   Joe Raedle/Getty Images\nLast week, I wrote a ...
# 1   Zach Boyden-Holmes/The Register\nPolice have i...
# 2   Chicago police are investigating whether Steph...
# 3   NASHVILLE, Tenn. -- No. 5 Georgia, coming off ...
# 4
# 5
# 6   OSCAR-WINNER Brie Larson has spoken out in sup...
# 7   RACHEL MARTIN, HOST:\n"Blade Runner" is back. ...
# 8   MANAGUA: Hurricane Nate may strengthen on Satu...
# 9   Board meeting for approval of Q2 unaudited fin...
# 10
# 11  SWEDISH TECH AND communications giant Ericsson...
# 12  After forming a joint venture with Marriott In...
# 13  PanOptica Secures $11 Million to Advance Clini...
# 14  “The Sell Sider” is a column written by the se...
# 15  The team who discovered gravitational waves - ...
# 16  Wauconda Area Library patrons can share ideas ...
# 17  This morning, Judge William Alsup ruled that t...
# 18  Two days after the mass shooting at Las Vegas'...
# 19  Hurricane Nate sent US Gulf Coast residents sc...
# 20  MEXICO CITY—A former Mexican state governor wh...
# 21  “Scandal” Season 7 lead star Kerry Washington ...
# 22  The Miami University RedHawks hockey team is h...
# 23  , Jose Altuve and the high-powered Astros led ...
# 24  Large-scale, high-profile shootings such as th...
# 25  One race-day variable that I see runners strug...
# 26  Moody’s Investor Service has upgraded 4Finance...
# 27  KEMP Technologies today announced that KEMP360...
# 28  Political events in the Bay Area\nPolitics and...
# 29
# ..                                                ...
# 70  ALEXANDRIA, Minn. — Earl Melchert wasn’t suppo...
# 71  With reference to above, please find voting re...
# 72  Intezyne Closes Oversubscribed $10M Series A F...
# 73  Cytel Inc., a leading biometrics CRO and clini...
# 74  Cardinal George Pell's barrister has told the ...
# 75  WASHINGTON (AP) — House Democrats are asking t...
# 76  MEDFORD, N.J. — A New Jersey man who spent dec...
# 77
# 78  For Mike Herndon, games played, career starts ...
# 79  AP\nGoogle has been transplanting knowledge in...
# 80  Metrolink unveiled its first-ever clean diesel...
# 81  Japan's top government spokesman said on Frida...
# 82  A Polk County district court judge will decide...
# 83  NEW ORLEANS — The U.S. Gulf Coast braced Frida...
# 84  Councils have claimed Whitehall is refusing to...
# 85  Pretty much the last thing you should expect i...
# 86  Tonight is the night that National Hockey Leag...
# 87  ESPN's College Game Day was in Fort Worth Satu...
# 88  Some people prescribe tax cuts whenever the qu...
# 89  The U.S. Bureau of Alcohol, Tobacco, Firearms ...
# 90  Ahmed Kutucu scored the tournament’s first goa...
# 91  Last night, the Washington Post reported that ...
# 92  Oct. 5 (UPI) -- A driver on an Australian road...
# 93  Whenever someone discusses sports video games,...
# 94  Jaylon Vela has just become the most celebrate...
# 95  Google's accelerating its push into making its...
# 96  (Reuters) - Firebrand Australian Nick Kyrgios ...
# 97  In the week running up to the collapse of Mona...
# 98  by Georgina Safe\nThere is a growing place in ...
# 99  Iowa State's upset win against Oklahoma got mo...
#
#                                          cleaned_text               category
# 0   joe raedlegetty image last week wrote story sl...    domestic/local news
# 1   zach boydenholmesthe register police identifie...    domestic/local news
# 2   chicago police investigating whether stephen p...    domestic/local news
# 3   nashville tenn 5 georgia coming two impressive...                 sports
# 4                                                        domestic/local news
# 5                                                        domestic/local news
# 6   oscarwinner brie larson spoken support fellow ...  entertainment/culture
# 7   rachel martin host blade runner back sure harr...  entertainment/culture
# 8   managua hurricane nate may strengthen saturday...    domestic/local news
# 9   board meeting approval q2 unaudited financial ...               business
# 10                                                       domestic/local news
# 11  swedish tech communication giant ericsson anno...               business
# 12  forming joint venture marriott international a...                   tech
# 13  panoptica secures 11 million advance clinical ...               business
# 14  “the sell sider” column written sell side digi...                   tech
# 15  team discovered gravitational wave ripple spac...  entertainment/culture
# 16  wauconda area library patron share idea improv...               business
# 17  morning judge william alsup ruled waymo v uber...    domestic/local news
# 18  two day mass shooting la vega route 91 harvest...  entertainment/culture
# 19  hurricane nate sent gulf coast resident scramb...    domestic/local news
# 20  mexico city—a former mexican state governor fu...    domestic/local news
# 21  “scandal” season 7 lead star kerry washington ...  entertainment/culture
# 22  miami university redhawks hockey team honoring...                 sports
# 23  jose altuve highpowered astros led major run h...                 sports
# 24  largescale highprofile shooting horrific happe...    domestic/local news
# 25  raceday variable see runner struggle weather s...  entertainment/culture
# 26  moody’s investor service upgraded 4finance‘s c...               business
# 27  kemp technology today announced kemp360 centra...                   tech
# 28  political event bay area politics medium longt...                 sports
# 29                                                       domestic/local news
# ..                                                ...                    ...
# 70  alexandria minn — earl melchert wasn’t suppose...  entertainment/culture
# 71  reference please find voting result along scru...               business
# 72  intezyne close oversubscribed 10m series finan...               business
# 73  cytel inc leading biometrics cro clinical tria...               business
# 74  cardinal george pells barrister told court cla...    domestic/local news
# 75  washington ap — house democrat asking trump ad...    domestic/local news
# 76  medford nj — new jersey man spent decade prepa...    domestic/local news
# 77                                                       domestic/local news
# 78  mike herndon game played career start tackle d...  entertainment/culture
# 79  ap google transplanting knowledge pixel line p...                   tech
# 80  metrolink unveiled firstever clean diesel loco...               business
# 81  japan top government spokesman friday importan...               business
# 82  polk county district court judge decide whethe...    domestic/local news
# 83  new orleans — gulf coast braced friday fastmov...    domestic/local news
# 84  council claimed whitehall refusing meet promis...    domestic/local news
# 85  pretty much last thing expect penguin coach mi...  entertainment/culture
# 86  tonight night national hockey league sport fan...                 sports
# 87  espns college game day fort worth saturday mor...                 sports
# 88  people prescribe tax cut whenever question acc...               business
# 89  bureau alcohol tobacco firearm explosive could...    domestic/local news
# 90  ahmed kutucu scored tournament’s first goal tu...                 sports
# 91  last night washington post reported fema remov...    domestic/local news
# 92  oct 5 upi driver australian road forced stop p...  entertainment/culture
# 93  whenever someone discus sport video game fifa ...  entertainment/culture
# 94  jaylon vela become celebrated athlete san jaci...                 sports
# 95  google accelerating push making device firm in...                   tech
# 96  reuters firebrand australian nick kyrgios beli...  entertainment/culture
# 97  week running collapse monarch airline crew mem...    domestic/local news
# 98  georgina safe growing place fashion creed colo...  entertainment/culture
# 99  iowa state upset win oklahoma got painful soon...                 sports
#
# [100 rows x 4 columns]

# %% [markdown]
# # Areas of Improvement
#
# There are a few areas where I feel the classification can be improved.
#
# 1. We could have done more fine tuning in the cleaning of the documents. This could have allowed for more concise and more distinct topic labels. Additionally, we could have removed the entries where the 'text' field was blank.
#
# 2. Determining the number of topics seemed very rough and arbitrary. Perhaps there is a more formal way to get a more effective number of topics. I can see that deciding there are too many topics can lead to 'overfitting' for a lack of a better term, when the goal is to simply categorize.
#
# 3. Recall we picked the topic with the highest probability to label each document. This leaves plenty of room for error. If we fine-tuned the number of topics and number of words for each topic, we could probably get the probabilities to be much higher when labeling the documents.
#
# Overall, I feel this was a decent starting point for filtering out which documents to hone in on. As a possible next step, I think it would be interesting to apply what I had done on the text of the articles to just the titles themselves, or perhaps including the title in the text (new column with text and title appended). Although the model can be improved, I believe it offers a solid platform for determining the more relevant articles that are of interest to Crunchbase.
